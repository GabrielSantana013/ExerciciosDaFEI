# %% [markdown]
# Com base no arquivo water_potability.csv responder as seguintes questões:
# Coloque a resposta correta no campo indicado.
# Usar vírgula na resposta.
#
# a) Determinar o números de linhas do dataset.
# número de linhas= Resposta 1 Questão 1
# 3276
#
# b) Determinar o coeficiente de correlação entre as variáveis solids e sulfate.
# Usar duas casas decimais.
# coeficiente de correlação linear = Resposta 2 Questão 1
# 0,00
#
# c) Calcular o coeficiente angular e o coeficiente linear da reta y(x)=ax+b, sendo x a variável hardness e  y a variável solids. Determinar o coeficiente de determinação R2 do ajuste. Usar duas casas decimais.
# coeficiente angular=  Resposta 3 Questão 1
# -14,10
# coeficiente linear=  Resposta 4 Questão 1
# 24681,84
# R2=  Resposta 5 Questão 1
# 0,00
#
# d) Fazer uma regressão múltipla sendo y a variável dependente e x a variável independente. Definir como y a variável Chloramines e como x as variáveis: Sulfate,Conductivity,Organic_carbon. Calcular o coeficiente de determinação R2 e o valor do p_valor  menos significativa. Usar três casas decimais.
# R2 =  Resposta 6 Questão 1
# 0,001
# p_valor =Resposta 7 Questão 1
# 0,773

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets
df = pd.read_csv('~/Downloads/water_potability.csv', header=(0))
print("Número de linhas e colunas:",df.shape)
df.head(25)

df = df.dropna()
# Out:
# Número de linhas e colunas: (3276, 10)
# Número de linhas e colunas: (2011, 10)

# %%
df.columns = [ x.replace('.','') for x in df.columns ]
df.head()
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0

# %%
import seaborn as sns
import statsmodels.formula.api as sm
model = sm.ols(formula='Solids ~ Hardness', data=df)

result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Solids   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     5.717
# Date:                Mon, 22 Sep 2025   Prob (F-statistic):             0.0169
# Time:                        20:24:30   Log-Likelihood:                -21079.
# No. Observations:                2011   AIC:                         4.216e+04
# Df Residuals:                    2009   BIC:                         4.217e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.468e+04   1172.080     21.058      0.000    2.24e+04     2.7e+04
# ...

# %%
model = sm.ols(formula="Chloramines ~ Sulfate + Conductivity + Organic_carbon", data=df)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            Chloramines   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9292
# Date:                Mon, 22 Sep 2025   Prob (F-statistic):              0.426
# Time:                        20:24:45   Log-Likelihood:                -3777.6
# No. Observations:                2011   AIC:                             7563.
# Df Residuals:                    2007   BIC:                             7586.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          7.4459      0.374     19.914      0.000       6.713       8.179
# ...
